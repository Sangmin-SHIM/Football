# %%
import pandas as pd
import re
import os

# All Players
FILE_BASE_PATH=f"C:/Users/ssm47/Desktop/Git (Projets Perso)/Football/Data/Csv/Bs4_results/Players/All-Players"
df_all=pd.read_csv(f'{FILE_BASE_PATH}/All_Players.csv')

# %%
df_all[df_all["No"]<20]
# Out:
#     No              Player                                     Link  \
# 0    0       Iker-Casillas       /en/players/1ddbb0da/Iker-Casillas
# 1    1      Roberto-Carlos      /en/players/6a3aaf62/Roberto-Carlos
# 2    2      Michel-Salgado      /en/players/68f36bc6/Michel-Salgado
# 3    3       Ivan-Helguera       /en/players/44151558/Ivan-Helguera
# 4    4           Luis-Figo           /en/players/f20f347f/Luis-Figo
# 5    5     Zinedine-Zidane     /en/players/654f4e63/Zinedine-Zidane
# 6    6                Raul                /en/players/2b81295d/Raul
# 7    7     Claude-Makelele     /en/players/c27d01de/Claude-Makelele
# 8    8             Ronaldo             /en/players/57feb553/Ronaldo
# 9    9     Fernando-Hierro     /en/players/2f926dd0/Fernando-Hierro
# 10  10    Flavio-Conceicao    /en/players/8783b7ca/Flavio-Conceicao
# 11  11                Guti                /en/players/dd0a0fa1/Guti
# 12  12   Esteban-Cambiasso   /en/players/4d801075/Esteban-Cambiasso
# 13  13     Francisco-Pavon     /en/players/a222a596/Francisco-Pavon
# 14  14     Santiago-Solari     /en/players/e34c6e97/Santiago-Solari
# 15  15     Steve-McManaman     /en/players/9be05f40/Steve-McManaman
# 16  16     Oscar-Minambres     /en/players/8e27322b/Oscar-Minambres
# 17  17  Fernando-Morientes  /en/players/bceebb25/Fernando-Morientes
# 18  18     Javier-Portillo     /en/players/99058498/Javier-Portillo
# 19  19          Raul-Bravo          /en/players/65b9e56b/Raul-Bravo
#
#     Player_name(param) Player_id(param)
# 0        Iker-Casillas         1ddbb0da
# 1       Roberto-Carlos         6a3aaf62
# 2       Michel-Salgado         68f36bc6
# 3        Ivan-Helguera         44151558
# 4            Luis-Figo         f20f347f
# 5      Zinedine-Zidane         654f4e63
# 6                 Raul         2b81295d
# 7      Claude-Makelele         c27d01de
# 8              Ronaldo         57feb553
# 9      Fernando-Hierro         2f926dd0
# 10    Flavio-Conceicao         8783b7ca
# 11                Guti         dd0a0fa1
# 12   Esteban-Cambiasso         4d801075
# 13     Francisco-Pavon         a222a596
# 14     Santiago-Solari         e34c6e97
# 15     Steve-McManaman         9be05f40
# 16     Oscar-Minambres         8e27322b
# 17  Fernando-Morientes         bceebb25
# 18     Javier-Portillo         99058498
# 19          Raul-Bravo         65b9e56b
